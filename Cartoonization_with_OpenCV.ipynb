# %%
from google.colab import files
from IPython import display

# %%
image=files.upload()
# Out:
#      <input type="file" id="files-97587989-ddf1-4d7e-bf25-44ea3f1e7952" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97587989-ddf1-4d7e-bf25-44ea3f1e7952">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lathaa pic.jpeg to lathaa pic.jpeg

# %%
import cv2

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
num_down=2
num_bilateral=7

# %%
img_rgb=cv2.imread("lathaa pic.jpeg")
print(img_rgb.shape)
# Out:
# (1280, 959, 3)

# %%
img_rgb=cv2.resize(img_rgb,(800,800))

# %%
img_color=img_rgb
for _ in range(num_down):
  img_color=cv2.pyrDown(img_color)

# %%
for _ in range(num_bilateral):
  img_color=cv2.bilateralFilter(img_color,d=9,sigmaColor=9,sigmaSpace=7)

# %%
for _ in range(num_down):
  img_color=cv2.pyrUp(img_color)

# %%
img_gray=cv2.cvtColor(img_rgb,cv2.COLOR_RGB2GRAY)
img_blur=cv2.medianBlur(img_gray,7)
img_edge=cv2.adaptiveThreshold(img_blur,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,blockSize=9,C=2)

# %%
img_edge=cv2.cvtColor(img_edge,cv2.COLOR_GRAY2RGB)
img_cartoon=cv2.bitwise_and(img_color,img_edge)

# %%
cv2_imshow(img_cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7F52B2222F60>
